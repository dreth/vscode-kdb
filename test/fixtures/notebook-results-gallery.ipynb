# %%
savedTable
# Out:
# KX/q result: 3 rows; 3 saved here.

# %%
select from largeTable
# Out:
# KX/q result: 128 rows; 6 saved here.

# %%
gallery candlestick chart
# Out:
# KX/q candlestick gallery: 6 rows.
